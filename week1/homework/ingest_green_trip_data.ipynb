# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-09.csv.gz -o green_tripdata.csv.gz

# %%
# !ls
# Out:
# 1_GCP_terraform
# Dockerfile
# Homework 1.ipynb
# Ingest_CSV_data_to_postgres_container.ipynb
# Ingest_taxi_zone_lookup.ipynb
# commands.sh
# docker-compose.yaml
# green_tripdata.csv.gz
# green_tripdata_2019-09.csv.gz
# ingest_CSV_data_to_postgres_container.py
# notes
# ny_taxi_postgres_data
# output.csv
# pipeline.py
# requirements.txt
# taxi+_zone_lookup.csv
# venv
# yellow_trip_head100.csv
# yellow_tripdata_2021-01.csv

# %%
import pandas as pd
df = pd.read_csv('green_tripdata_2019-09.csv')
# Out:
# /var/folders/2b/z_nk1rc11d9cjs8512n4npk80000gn/T/ipykernel_44053/1141611588.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('green_tripdata_2019-09.csv')

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# 3         1.0           145           112              1.0           1.73
# 4         1.0           112           198              1.0           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# 3         1.0           145           112              1.0           1.73
# 4         1.0           112           198              1.0           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:2345/ny_taxi')

# %%
engine.connect()

# %%
df.head(n=0).to_sql(con=engine, name='green_trip_data', if_exists='replace')
# Out:
# 0

# %%
df.to_sql(con=engine, name='green_trip_data', if_exists='append')
# Out:
# 63
